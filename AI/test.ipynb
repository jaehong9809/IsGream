# %%
import torch

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='best.pt')
# Out:
# Using cache found in C:\Users\SSAFY/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2025-1-14 Python-3.10.11 torch-2.5.1+cpu CPU
#
# Fusing layers...
# Model summary: 574 layers, 140105440 parameters, 0 gradients, 208.2 GFLOPs
# Adding AutoShape...

# %%
results = model('img1.png')
results.show()  # 화면에 결과 출력
# Out:
# C:\Users\SSAFY/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=1728x1080>

# %%
results.save()  # 결과 저장
# Out:
# Saved 1 image to runs\detect\exp

# %%
results = model('img2.jpg')
# Out:
# C:\Users\SSAFY/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
results.save(save_dir='./result_img')  # 결과 저장
# Out:
# Saved 1 image to result_img
